# %%
import numpy as np                #note- pandas builtin desingned for quick analysis

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline                   #so that we can see the visalization plot

# %%
df1=pd.read_csv('df1',index_col=0)# for col 1st

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2=pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist()              #for directly make a histogram plot easily,in the paranthesis matplotlib
                             #argumet can be pass like bins

# %%
df1['A'].hist(bins=100)    #can pass the bins values accoradainly from 
                           #afetr imorting seaborn it will looke more nice

# %%
df1['A'].plot(kind='hist',bins=100)               # we can also plot bby this methos

# %%
df1['A'].plot.hist()           # we can directly implement

# %%
df2.plot.area()              #for area plot

# %%
# if yu want any transparamcy in teh graph then put the value of alpha in area plot
df2.plot.area(alpha=0.3)            #0.1---more transparant             0.9----------lesstransparent

# %%
#Bar plot
df2.plot.bar()

# %%
# if yu want to stacking the value in bar graph
df2.plot.bar(stacked=True)

# %% [markdown]
# # Line plot

# %%
df1.plot.line(x='A',y='B')

# %%
# as trrributes are belongs to matplotlib so we can pass arguments like figsize lw(width) etc
df1.plot.line(x='A',y='B',figsize=(12,3),lw=3)

# %% [markdown]
# # scatter plots

# %%
df1.plot.scatter(x='A',y='B')

# %%
# if yu want a third argument as  different cplour then yu have to put as a c=colour
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')          #for different palette opt cmap

# %%
# if yu wanna change the size of the c with respect to A and B then
df1.plot.scatter(x='A',y='B',s=df1['C']*70 ) #size is too small so we have to multiply

# %% [markdown]
# # Box plot

# %%
df2.plot.box()

# %%
df=pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])

# %%
df.head()
# Out:
#           a         b
# 0  0.518409 -0.717452
# 1  0.387164 -0.405519
# 2  0.649952 -0.656507
# 3 -0.671097 -0.639594
# 4 -1.021943  0.812134

# %% [markdown]
# # Hex plot

# %%
df.plot.hexbin(x='a',y='b')

# %%
# size is very small so we can pass gridsize
df.plot.hexbin(x='a',y='b',gridsize=20,cmap='coolwarm')                     #100 =less size
                                                            #10= more size

# %% [markdown]
# # Kernal density estimation plot

# %%
df['a'].plot.kde()

# %%
#kde plot for all columns
df1.plot.kde()
